# %%
def myfunc(*args):
    list = []
    for i in args:
        if i % 2 == 0:
            list.append(i)
    return list

# %%
myfunc(1,2,3,4,5)
# Out:
# [2, 4]

# %%
def myfunc(*args):
    index = 0
    string = ""
    for letter in args[0]:
        if(index % 2 == 0):
            letter = letter.lower()
        else:
            letter = letter.upper()
        string += letter
        index += 1
    print(string)

# %%
myfunc("Anthropology")
# Out:
# aNtHrOpOlOgY
